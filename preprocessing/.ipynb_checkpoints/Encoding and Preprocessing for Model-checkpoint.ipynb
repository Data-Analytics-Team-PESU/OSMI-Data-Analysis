# %% [markdown]
# # Encoding Features

# %% [markdown]
# Since we need to feed this data to the mode, we need to encode the categorical features

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import pie
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("../datasets/final_preprocessed.csv")
df.shape
# Out:
# (1246, 54)

# %% [markdown]
# ## Analysing the features

# %%
df.head()
# Out:
#    Timestamp  Are you self-employed?  \
# 0       2017                       0
# 1       2017                       0
# 2       2017                       0
# 3       2017                       0
# 4       2017                       0
#
#   How many employees does your company or organization have?  \
# 0                                            100-500
# 1                                            100-500
# 2                                               6-25
# 3                                            100-500
# 4                                               6-25
#
#   Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#   Is your primary role within your company related to tech/IT?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                0.0
# 4                                                1.0
#
#   Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                                                 No
# 1                                                Yes
# 2                                       I don't know
# 3                                                Yes
# 4                                                Yes
#
#   Do you know the options for mental health care available under your employer-provided health coverage?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                 No
# 3                                                 No
# 4                                                Yes
#
#   Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                                 No
# 1                                                 No
# 2                                       I don't know
# 3                                                 No
# 4                                                 No
#
#   Does your employer offer resources to learn more about mental health disorders and options for seeking help?  \
# 0                                       I don't know
# 1                                                 No
# 2                                                 No
# 3                                       I don't know
# 4                                                 No
#
#   Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                       I don't know
# 1                                       I don't know
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Are you openly identified at work as a person with a mental health issue?  \
# 0                                                0.0
# 1                                                0.0
# 2                                                1.0
# 3                                                0.0
# 4                                                1.0
#
#   If they knew you suffered from a mental health disorder, how do you think that your team members/co-workers would react?  \
# 0                                               10.0
# 1                                                6.0
# 2                                                5.0
# 3                                                4.0
# 4                                                5.0
#
#   Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?  \
# 0                                 Yes, I experienced
# 1                                    Yes, I observed
# 2                                 Yes, I experienced
# 3                                    Yes, I observed
# 4                                                 No
#
#   Have you observed or experienced a supportive or well handled response to a mental health issue in your current or previous workplace?  \
# 0                                 Yes, I experienced
# 1                                     Maybe/Not sure
# 2                                 Yes, I experienced
# 3                                    Yes, I observed
# 4                                    Yes, I observed
#
#   Overall, how well do you think the tech industry supports employees with mental health issues?  \
# 0                                                1.0
# 1                                                2.0
# 2                                                1.0
# 3                                                2.0
# 4                                                2.0
#
#   What is your age? What is your gender?  What country do you live in?  \
# 0              27.0               female                United Kingdom
# 1              31.0                 male                United Kingdom
# 2              36.0                 male      United States of America
# 3              30.0                 male      United States of America
# 4              36.0               female      United States of America
#
#    What is your race?  What country do you work in?
# 0           Caucasian                United Kingdom
# 1           Caucasian                United Kingdom
# 2           Caucasian      United States of America
# 3           Caucasian      United States of America
# 4               Asian      United States of America
#
# [5 rows x 54 columns]

# %%
df.isnull().values.any()
# Out:
# False

# %%
cnt=0
for i in df.columns:
    print(cnt, df[i].dtype)
    cnt+=1
# Out:
# 0 int64
# 1 int64
# 2 object
# 3 object
# 4 object
# 5 object
# 6 object
# 7 object
# 8 object
# 9 object
# 10 object
# 11 object
# 12 object
# 13 object
# 14 object
# 15 object
# 16 object
# 17 float64
# 18 float64
# 19 int64
# 20 object
# 21 object
# 22 object
# 23 object
# 24 object
# 25 object
# 26 object
# 27 object
# 28 object
# 29 object
# 30 object
# 31 object
# 32 float64
# 33 float64
# 34 object
# 35 object
# 36 int64
# 37 object
# 38 object
# 39 object
# 40 object
# 41 int64
# 42 object
# 43 object
# 44 float64
# 45 float64
# 46 object
# 47 object
# 48 float64
# 49 float64
# 50 object
# 51 object
# 52 object
# 53 object

# %%
obj_df = df.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#   How many employees does your company or organization have?  \
# 0                                            100-500
# 1                                            100-500
# 2                                               6-25
# 3                                            100-500
# 4                                               6-25
#
#   Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#   Is your primary role within your company related to tech/IT?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                0.0
# 4                                                1.0
#
#   Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                                                 No
# 1                                                Yes
# 2                                       I don't know
# 3                                                Yes
# 4                                                Yes
#
#   Do you know the options for mental health care available under your employer-provided health coverage?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                 No
# 3                                                 No
# 4                                                Yes
#
#   Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                                 No
# 1                                                 No
# 2                                       I don't know
# 3                                                 No
# 4                                                 No
#
#   Does your employer offer resources to learn more about mental health disorders and options for seeking help?  \
# 0                                       I don't know
# 1                                                 No
# 2                                                 No
# 3                                       I don't know
# 4                                                 No
#
#   Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                       I don't know
# 1                                       I don't know
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?  \
# 0                                       I don't know
# 1                                       I don't know
# 2                                          Difficult
# 3                                      Somewhat easy
# 4                                          Very easy
#
#   Would you feel more comfortable talking to your coworkers about your physical health or your mental health?  \
# 0                     Same level of comfort for each
# 1                     Same level of comfort for each
# 2                     Same level of comfort for each
# 3                                    Physical health
# 4                     Same level of comfort for each
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   If you have a mental health disorder, how often do you feel that it interferes with your work when NOT being treated effectively (i.e., when you are experiencing symptoms)?  \
# 0                                          Sometimes
# 1                                          Sometimes
# 2                                          Sometimes
# 3                               Not applicable to me
# 4                                              Often
#
#   Have your observations of how another individual who discussed a mental health issue made you less likely to reveal a mental health issue yourself in your current workplace?  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                              Maybe
# 4                                                 No
#
#   Would you be willing to bring up a physical health issue with a potential employer in an interview?  \
# 0                                                Yes
# 1                                                Yes
# 2                                              Maybe
# 3                                              Maybe
# 4                                                 No
#
#   Would you bring up your mental health with a potential employer in an interview?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?  \
# 0                                 Yes, I experienced
# 1                                    Yes, I observed
# 2                                 Yes, I experienced
# 3                                    Yes, I observed
# 4                                                 No
#
#   Have you observed or experienced a supportive or well handled response to a mental health issue in your current or previous workplace?  \
# 0                                 Yes, I experienced
# 1                                     Maybe/Not sure
# 2                                 Yes, I experienced
# 3                                    Yes, I observed
# 4                                    Yes, I observed
#
#   What is your gender? What country do you live in? What is your race?  \
# 0               female               United Kingdom          Caucasian
# 1                 male               United Kingdom          Caucasian
# 2                 male     United States of America          Caucasian
# 3                 male     United States of America          Caucasian
# 4               female     United States of America              Asian
#
#   What country do you work in?
# 0               United Kingdom
# 1               United Kingdom
# 2     United States of America
# 3     United States of America
# 4     United States of America
#
# [5 rows x 41 columns]

# %%
obj_df.shape
# Out:
# (1246, 41)

# %%
obj_df.rename(columns={obj_df.columns[i]:df.columns.get_loc(obj_df.columns[i]) for i in range(obj_df.shape[1])}, inplace=True)

# %% [markdown]
# ## 1. Columns which have numeric values

# %% [markdown]
# These columns can be directly converted to numeric columns

# %%
numer_cols=[3,4,13,15,16,20,28,30,31]

# %%
df.loc[df[df.columns[0]] == 2018].groupby([df.columns[4]]).size()
# Out:
# Is your primary role within your company related to tech/IT?
# 0.0     14
# 1.0    300
# dtype: int64

# %%
cleanup_nums={df.columns[i]:{"True":1, "False":0} for i in numer_cols}

# %%
df = df.replace(cleanup_nums)

# %%
numer_cols=[3,4,13,15,16,20,28,30,31]
for i in numer_cols:
    df[df.columns[i]] = pd.to_numeric(df[df.columns[i]])
    df[df.columns[i]] = df[df.columns[i]].astype('int')

# %% [markdown]
# Now the conversion of columns which were already numerical is done successfully

# %% [markdown]
# ## 2. Columns which have categorical values

# %% [markdown]
# Here, we are going to replace the columns which have the following values
# - No (replaced with 0)
# - Yes (replaced with 1)
# - I don't know (replaced with 2)
# - Maybe (replaced with 3)

# %%
obj_df = df.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#   How many employees does your company or organization have?  \
# 0                                            100-500
# 1                                            100-500
# 2                                               6-25
# 3                                            100-500
# 4                                               6-25
#
#   Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                                                 No
# 1                                                Yes
# 2                                       I don't know
# 3                                                Yes
# 4                                                Yes
#
#   Do you know the options for mental health care available under your employer-provided health coverage?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                 No
# 3                                                 No
# 4                                                Yes
#
#   Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                                 No
# 1                                                 No
# 2                                       I don't know
# 3                                                 No
# 4                                                 No
#
#   Does your employer offer resources to learn more about mental health disorders and options for seeking help?  \
# 0                                       I don't know
# 1                                                 No
# 2                                                 No
# 3                                       I don't know
# 4                                                 No
#
#   Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                       I don't know
# 1                                       I don't know
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?  \
# 0                                       I don't know
# 1                                       I don't know
# 2                                          Difficult
# 3                                      Somewhat easy
# 4                                          Very easy
#
#   Would you feel more comfortable talking to your coworkers about your physical health or your mental health?  \
# 0                     Same level of comfort for each
# 1                     Same level of comfort for each
# 2                     Same level of comfort for each
# 3                                    Physical health
# 4                     Same level of comfort for each
#
#   Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?  \
# 0                                                Yes
# 1                                              Maybe
# 2                                                Yes
# 3                                              Maybe
# 4                                                Yes
#
#   Would you feel comfortable discussing a mental health issue with your coworkers?  \
# 0                                                Yes
# 1                                                Yes
# 2                                              Maybe
# 3                                              Maybe
# 4                                                 No
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   If you have a mental health disorder, how often do you feel that it interferes with your work when NOT being treated effectively (i.e., when you are experiencing symptoms)?  \
# 0                                          Sometimes
# 1                                          Sometimes
# 2                                          Sometimes
# 3                               Not applicable to me
# 4                                              Often
#
#   Have your observations of how another individual who discussed a mental health issue made you less likely to reveal a mental health issue yourself in your current workplace?  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                              Maybe
# 4                                                 No
#
#   Would you be willing to bring up a physical health issue with a potential employer in an interview?  \
# 0                                                Yes
# 1                                                Yes
# 2                                              Maybe
# 3                                              Maybe
# 4                                                 No
#
#   Would you bring up your mental health with a potential employer in an interview?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?  \
# 0                                 Yes, I experienced
# 1                                    Yes, I observed
# 2                                 Yes, I experienced
# 3                                    Yes, I observed
# 4                                                 No
#
#   Have you observed or experienced a supportive or well handled response to a mental health issue in your current or previous workplace?  \
# 0                                 Yes, I experienced
# 1                                     Maybe/Not sure
# 2                                 Yes, I experienced
# 3                                    Yes, I observed
# 4                                    Yes, I observed
#
#   What is your gender? What country do you live in? What is your race?  \
# 0               female               United Kingdom          Caucasian
# 1                 male               United Kingdom          Caucasian
# 2                 male     United States of America          Caucasian
# 3                 male     United States of America          Caucasian
# 4               female     United States of America              Asian
#
#   What country do you work in?
# 0               United Kingdom
# 1               United Kingdom
# 2     United States of America
# 3     United States of America
# 4     United States of America
#
# [5 rows x 32 columns]

# %%
obj_df.shape
# Out:
# (1246, 32)

# %%
yes_no_cols=[]
for i in obj_df.columns:
    if "Yes" in df[i].unique():
        print(df.columns.get_loc(i),df[i].unique())
        yes_no_cols.append(df.columns.get_loc(i))
print('\n',yes_no_cols)
# Out:
# 5 ['No' 'Yes' "I don't know" 'Not eligible for coverage / NA']
# 6 ['Yes' 'No']
# 7 ['No' "I don't know" 'Yes']
# 8 ["I don't know" 'No' 'Yes']
# 9 ["I don't know" 'Yes' 'No']
# 12 ['Yes' 'Maybe' 'No']
# 14 ['Yes' 'Maybe' 'No']
# 34 ['Possibly' 'Yes' 'No' "Don't Know"]
# 35 ['Possibly' 'Yes' 'No' "Don't Know"]
# 37 ['No' 'Yes' "I don't know"]
# 40 ['No' 'Yes' 'Maybe' 'No_Answer']
# 42 ['Yes' 'Maybe' 'No']
# 43 ['No' 'Yes' 'Maybe']
#
#  [5, 6, 7, 8, 9, 12, 14, 34, 35, 37, 40, 42, 43]

# %%
replace_dict={"No": 0, 'Yes':1, "I don't know":2, "Don't Know":2,"Maybe":2, "Not eligible for coverage / NA":3,'Possibly':3,'No_Answer':3 }

# %%
cleanup_nums={df.columns[i]:replace_dict for i in yes_no_cols}

# %%
df = df.replace(cleanup_nums)

# %%
df.head()
# Out:
#    Timestamp  Are you self-employed?  \
# 0       2017                       0
# 1       2017                       0
# 2       2017                       0
# 3       2017                       0
# 4       2017                       0
#
#   How many employees does your company or organization have?  \
# 0                                            100-500
# 1                                            100-500
# 2                                               6-25
# 3                                            100-500
# 4                                               6-25
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  0
# 4                                                  1
#
#    Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                                                  0
# 1                                                  1
# 2                                                  2
# 3                                                  1
# 4                                                  1
#
#    Do you know the options for mental health care available under your employer-provided health coverage?  \
# 0                                                  1
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  1
#
#    Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                                  0
# 1                                                  0
# 2                                                  2
# 3                                                  0
# 4                                                  0
#
#    Does your employer offer resources to learn more about mental health disorders and options for seeking help?  \
# 0                                                  2
# 1                                                  0
# 2                                                  0
# 3                                                  2
# 4                                                  0
#
#    Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                                  2
# 1                                                  2
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Are you openly identified at work as a person with a mental health issue?  \
# 0                                                0.0
# 1                                                0.0
# 2                                                1.0
# 3                                                0.0
# 4                                                1.0
#
#   If they knew you suffered from a mental health disorder, how do you think that your team members/co-workers would react?  \
# 0                                               10.0
# 1                                                6.0
# 2                                                5.0
# 3                                                4.0
# 4                                                5.0
#
#    Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?  \
# 0                                 Yes, I experienced
# 1                                    Yes, I observed
# 2                                 Yes, I experienced
# 3                                    Yes, I observed
# 4                                                 No
#
#    Have you observed or experienced a supportive or well handled response to a mental health issue in your current or previous workplace?  \
# 0                                 Yes, I experienced
# 1                                     Maybe/Not sure
# 2                                 Yes, I experienced
# 3                                    Yes, I observed
# 4                                    Yes, I observed
#
#    Overall, how well do you think the tech industry supports employees with mental health issues?  \
# 0                                                1.0
# 1                                                2.0
# 2                                                1.0
# 3                                                2.0
# 4                                                2.0
#
#    What is your age?  What is your gender?  What country do you live in?  \
# 0               27.0                female                United Kingdom
# 1               31.0                  male                United Kingdom
# 2               36.0                  male      United States of America
# 3               30.0                  male      United States of America
# 4               36.0                female      United States of America
#
#    What is your race?  What country do you work in?
# 0           Caucasian                United Kingdom
# 1           Caucasian                United Kingdom
# 2           Caucasian      United States of America
# 3           Caucasian      United States of America
# 4               Asian      United States of America
#
# [5 rows x 54 columns]

# %% [markdown]
# ## 3. Other Columns

# %%
obj_df = df.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#   How many employees does your company or organization have?  \
# 0                                            100-500
# 1                                            100-500
# 2                                               6-25
# 3                                            100-500
# 4                                               6-25
#
#   If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?  \
# 0                                       I don't know
# 1                                       I don't know
# 2                                          Difficult
# 3                                      Somewhat easy
# 4                                          Very easy
#
#   Would you feel more comfortable talking to your coworkers about your physical health or your mental health?  \
# 0                     Same level of comfort for each
# 1                     Same level of comfort for each
# 2                     Same level of comfort for each
# 3                                    Physical health
# 4                     Same level of comfort for each
#
#   Have your previous employers provided mental health benefits?  \
# 0                                       I don't know
# 1                                           Some did
# 2                                           Some did
# 3                                       No, none did
# 4                                           Some did
#
#   Were you aware of the options for mental health care provided by your previous employers?  \
# 0                                N/A (was not aware)
# 1                                I was aware of some
# 2                                N/A (was not aware)
# 3                                I was aware of some
# 4                                I was aware of some
#
#   Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?  \
# 0                                           Some did
# 1                                           None did
# 2                                           None did
# 3                                           None did
# 4                                           None did
#
#   Did your previous employers provide resources to learn more about mental health disorders and how to seek help?  \
# 0                                           Some did
# 1                                           None did
# 2                                           None did
# 3                                           Some did
# 4                                           None did
#
#   Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?  \
# 0                                        Yes, always
# 1                                       I don't know
# 2                                       I don't know
# 3                                        Yes, always
# 4                                        Yes, always
#
#   Would you have felt more comfortable talking to your previous employer about your physical health or your mental health?  \
# 0                                    Physical health
# 1                                    Physical health
# 2                                    Physical health
# 3                                    Physical health
# 4                     Same level of comfort for each
#
#   Would you have been willing to discuss your mental health with your direct supervisor(s)?  \
# 0                Yes, all of my previous supervisors
# 1                No, none of my previous supervisors
# 2                No, none of my previous supervisors
# 3                    Some of my previous supervisors
# 4                    Some of my previous supervisors
#
#   Would you have been willing to discuss your mental health with your coworkers at previous employers?  \
# 0               No, at none of my previous employers
# 1                   At some of my previous employers
# 2                   At some of my previous employers
# 3                   At some of my previous employers
# 4                   At some of my previous employers
#
#   If you have a mental health disorder, how often do you feel that it interferes with your work when being treated effectively?  \
# 0                                          Sometimes
# 1                               Not applicable to me
# 2                                          Sometimes
# 3                                             Rarely
# 4                                             Rarely
#
#   If you have a mental health disorder, how often do you feel that it interferes with your work when NOT being treated effectively (i.e., when you are experiencing symptoms)?  \
# 0                                          Sometimes
# 1                                          Sometimes
# 2                                          Sometimes
# 3                               Not applicable to me
# 4                                              Often
#
#   Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?  \
# 0                                 Yes, I experienced
# 1                                    Yes, I observed
# 2                                 Yes, I experienced
# 3                                    Yes, I observed
# 4                                                 No
#
#   Have you observed or experienced a supportive or well handled response to a mental health issue in your current or previous workplace?  \
# 0                                 Yes, I experienced
# 1                                     Maybe/Not sure
# 2                                 Yes, I experienced
# 3                                    Yes, I observed
# 4                                    Yes, I observed
#
#   What is your gender? What country do you live in? What is your race?  \
# 0               female               United Kingdom          Caucasian
# 1                 male               United Kingdom          Caucasian
# 2                 male     United States of America          Caucasian
# 3                 male     United States of America          Caucasian
# 4               female     United States of America              Asian
#
#   What country do you work in?
# 0               United Kingdom
# 1               United Kingdom
# 2     United States of America
# 3     United States of America
# 4     United States of America

# %%
obj_df.shape
# Out:
# (1246, 19)

# %%
for i in obj_df.columns:
    print(df.columns.get_loc(i),df[i].unique())
# Out:
# 2 ['100-500' '6-25' '26-100' 'More than 1000' '500-1000' '1-5']
# 10 ["I don't know" 'Difficult' 'Somewhat easy' 'Very easy'
#  'Neither easy nor difficult' 'Somewhat difficult']
# 11 ['Same level of comfort for each' 'Physical health' 'Mental health']
# 21 ["I don't know" 'Some did' 'No, none did' 'Yes, they all did']
# 22 ['N/A (was not aware)' 'I was aware of some' 'N/A (none offered)'
#  'Yes, I was aware of all of them' 'No, I only became aware later']
# 23 ['Some did' 'None did' "I don't know" 'Yes, they all did']
# 24 ['Some did' 'None did' 'Yes, they all did']
# 25 ['Yes, always' "I don't know" 'Sometimes' 'No']
# 26 ['Physical health' 'Same level of comfort for each' 'Mental health']
# 27 ['Yes, all of my previous supervisors'
#  'No, none of my previous supervisors' 'Some of my previous supervisors'
#  "I don't know"]
# 29 ['No, at none of my previous employers' 'At some of my previous employers'
#  'Yes, at all of my previous employers' 'Some of my previous employers']
# 38 ['Sometimes' 'Not applicable to me' 'Rarely' 'Often' 'Never']
# 39 ['Sometimes' 'Not applicable to me' 'Often' 'Rarely' 'Never']
# 46 ['Yes, I experienced' 'Yes, I observed' 'No' 'Maybe/Not sure']
# 47 ['Yes, I experienced' 'Maybe/Not sure' 'Yes, I observed' 'No']
# 50 ['female' 'male' 'other' 'let\'s keep it simple and say "male"' 'make']
# 51 ['United Kingdom' 'United States of America' 'Switzerland' 'Bangladesh'
#  'Germany' 'Canada' 'Israel' 'Iceland' 'Japan' 'Indonesia' 'India'
#  'Portugal' 'Czech Republic' 'Finland' 'Australia' 'South Africa' 'Sweden'
#  'Spain' 'Hungary' 'Bulgaria' 'Italy' 'Romania' 'Argentina' 'Greece'
#  'France' 'Ireland' 'Mexico' 'Netherlands' 'New Zealand' 'Poland'
#  'Belgium' 'Singapore' 'Slovakia' 'Turkey' 'Norway' 'Russia' 'Colombia'
#  'Ukraine' 'Estonia' 'Brazil' 'Mauritius' 'Nigeria' 'Uruguay' 'Ethiopia'
#  'Macedonia' 'Hong Kong' 'Croatia' 'Pakistan' 'Philippines' 'Chile'
#  'Mongolia' 'Egypt' 'Sri Lanka']
# 52 ['Caucasian' 'Asian' 'Afrcian American' 'Mixed' 'Did not answer'
#  'American Indian or Alaska Native' 'Hispanic']
# 53 ['United Kingdom' 'United States of America' 'Switzerland' 'Bangladesh'
#  'Germany' 'Canada' 'Israel' 'Iceland' 'Japan' 'Indonesia' 'India'
#  'Portugal' 'Finland' 'Australia' 'South Africa' 'Sweden' 'Spain'
#  'Hungary' 'Bulgaria' 'Italy' 'Romania' 'Argentina' 'Austria'
#  'Netherlands' 'France' 'Mexico' 'Swaziland' 'Ireland' 'New Zealand'
#  'Poland' 'Belgium' 'Singapore' 'Slovakia' 'Luxembourg' 'Turkey' 'Norway'
#  'Russia' 'Colombia' 'Ukraine' 'Estonia' 'Brazil' 'Mauritius' 'Nigeria'
#  'Uruguay' 'Ethiopia' 'Macedonia' 'Hong Kong' 'Croatia' 'Other' 'Pakistan'
#  'Greece' 'Philippines' 'Mongolia' 'Egypt' 'Sri Lanka']

# %% [markdown]
# ### Dealing with `How many employees does your company or organization have?` attribute

# %% [markdown]
# Here, each range will be replaced by the average, since it will be indicative of the range

# %%
print(df[df.columns[2]].unique())
# Out:
# ['100-500' '6-25' '26-100' 'More than 1000' '500-1000' '1-5']

# %%
replace_dict={'1-5':3, '6-25':15, '26-100':63, '100-500':300, '500-1000':750, 'More than 1000':1000 }

# %%
df = df.replace({df.columns[2]:replace_dict})

# %%
print(df[df.columns[2]].unique())
# Out:
# [ 300   15   63 1000  750    3]

# %% [markdown]
# ### Other columns

# %% [markdown]
# The rest of the columns will be encoded using **Label Encoding**

# %%
obj_df = df.select_dtypes(include=['object']).copy()
obj_df.shape
# Out:
# (1246, 18)

# %%
for i in obj_df.columns:
    df[i] = df[i].astype('category')
    df[i] = df[i].cat.codes

# %%
df.head()
# Out:
#    Timestamp  Are you self-employed?  \
# 0       2017                       0
# 1       2017                       0
# 2       2017                       0
# 3       2017                       0
# 4       2017                       0
#
#    How many employees does your company or organization have?  \
# 0                                                300
# 1                                                300
# 2                                                 15
# 3                                                300
# 4                                                 15
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  0
# 4                                                  1
#
#    Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                                                  0
# 1                                                  1
# 2                                                  2
# 3                                                  1
# 4                                                  1
#
#    Do you know the options for mental health care available under your employer-provided health coverage?  \
# 0                                                  1
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  1
#
#    Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                                  0
# 1                                                  0
# 2                                                  2
# 3                                                  0
# 4                                                  0
#
#    Does your employer offer resources to learn more about mental health disorders and options for seeking help?  \
# 0                                                  2
# 1                                                  0
# 2                                                  0
# 3                                                  2
# 4                                                  0
#
#    Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                                  2
# 1                                                  2
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Are you openly identified at work as a person with a mental health issue?  \
# 0                                                0.0
# 1                                                0.0
# 2                                                1.0
# 3                                                0.0
# 4                                                1.0
#
#    If they knew you suffered from a mental health disorder, how do you think that your team members/co-workers would react?  \
# 0                                               10.0
# 1                                                6.0
# 2                                                5.0
# 3                                                4.0
# 4                                                5.0
#
#    Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?  \
# 0                                                  2
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  1
#
#    Have you observed or experienced a supportive or well handled response to a mental health issue in your current or previous workplace?  \
# 0                                                  2
# 1                                                  0
# 2                                                  2
# 3                                                  3
# 4                                                  3
#
#    Overall, how well do you think the tech industry supports employees with mental health issues?  \
# 0                                                1.0
# 1                                                2.0
# 2                                                1.0
# 3                                                2.0
# 4                                                2.0
#
#    What is your age?  What is your gender?  What country do you live in?  \
# 0               27.0                     0                            50
# 1               31.0                     3                            50
# 2               36.0                     3                            51
# 3               30.0                     3                            51
# 4               36.0                     0                            51
#
#    What is your race?  What country do you work in?
# 0                   3                            52
# 1                   3                            52
# 2                   3                            53
# 3                   3                            53
# 4                   2                            53
#
# [5 rows x 54 columns]

# %%
cnt=0
for i in df.columns:
    if df[i].dtype=='object':
        print("YES")

# %% [markdown]
# #### We have successfully encoded the entire dataset

# %%
df.to_csv('../datasets/final.csv')

# %% [markdown]
# ### Now this dataset will be used to create the model
